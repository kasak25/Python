# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 5</b></center>
# <center><b><h3>Roll No.:245</b></center>
# <center><b><h3>Name:kasak suchak</b></center>
# <pre>

# %% [markdown]
# ### 1) Character Category Counter
# **Problem:** Count uppercase, lowercase, digits, and special characters in a string.
#
# **Sample Inputs & Outputs:**
# - Input: `Python3@Lab` → Uppercase: 2, Lowercase: 7, Digits: 1, Special: 1
# - Input: `HELLO123` → Uppercase: 5, Lowercase: 0, Digits: 3, Special: 0
# - Input: `hi@#9` → Uppercase: 0, Lowercase: 2, Digits: 1, Special: 2

# %%
s = input('enter string')
Uppercase = 0
Lowercase = 0
Digits = 0
Special = 0
for i in s:
    if i.isupper():
        Uppercase += 1 
    elif i.islower():
        Lowercase += 1
    elif i.isdigit():
        Digits += 1
    else:
        Special += 1
print(f'Uppercase:{Uppercase},Lowercase:{Lowercase},Digits:{Digits},Special:{Special}')
# Out:
# enter string Python3@Lab
# Uppercase:2,Lowercase:7,Digits:1,Special:1

# %% [markdown]
# ### 2) Reverse Each Word
# - Input: `Python is Easy` → `nohtyP si ysaE`
# - Input: `Hello World` → `olleH dlroW`
# - Input: `Learn Python Fast` → `nraeL nohtyP tsaF`

# %%
s1 = input('enter string').split(' ')
reverse = []
for i in s1:
    reverse.append(i[::-1])
ans = ' '.join(reverse)
print(ans)
# Out:
# enter string Python is Easy
# nohtyP si ysaE

# %% [markdown]
# ### 3) Case Pattern Identifier
# - `PYTHON` → Uppercase
# - `python` → Lowercase
# - `Python Programming` → Title Case

# %%
s = input('enter string:')
if s.isupper():
    print('Uppercase')
elif s.islower():
    print('Lower case')
else:
    print('Title case')
# Out:
# enter string: PYTHON
# Uppercase

# %% [markdown]
# ### 4) First and Last Occurrence Finder
# - `programming`, `g` → First:3 Last:10
# - `banana`, `a` → First:1 Last:5
# - `hello`, `z` → Not found

# %%
s = input('enter string:')
char = input('enter string:')
first = s.find(char)
last = s.rfind(char)
print(f'First:{first} last : {last}')
# Out:
# enter string: banana
# enter string: a
# First:1 last : 5

# %% [markdown]
# ### 5) Word Frequency Counter (ignore the case)
# - `Python is easy and Python is powerful` → python: 2
# - `Java is popular but java is verbose` → java: 2
# - `C is fast` → c:1

# %%
s = input('enter string:').lower()
word = input('enter string:').lower()
countword = s.count(word)
print(countword)
# Out:
# enter string: Python is easy and Python is powerful
# enter string: python
# 2

# %% [markdown]
# ### 6) Remove Extra Spaces
# - `  Python   is   fun  ` → `Python is fun`
# - `   Hello   World ` → `Hello World`
# - `NoExtraSpace` → `NoExtraSpace`

# %%
s = input('enter string:')
print(' '.join(s.split()))
# Out:
# enter string:   python   is    fun
# python is fun

# %% [markdown]
# ### 7) Prefix and Suffix Removal
# - `unhappy.txt` → `happy`
# - `pretest.py` → `test`
# - `unwanted.doc` → `wanted`

# %%
s = input('enter string:')
suff = input('enter suffix:')
pref = input('enter prefix:')
s = s.removeprefix(pref)
s = s.removesuffix(suff)
print(s)
# Out:
# enter string: unhappy.txt
# enter suffix: .txt
# enter prefix: un
# happy

# %% [markdown]
# ### 8) Replace Vowels
# - `Programming` → `Pr*gr*mm*ng`
# - `Education` → `*d*c*t**n`
# - `Sky` → `Sky`

# %%
s = input('enter string:')
for i in s:
    if(i in 'aieouAEIOU'):
        s=s.replace(i,'*')
print(s)
# Out:
# enter string: programming
# pr*gr*mm*ng

# %% [markdown]
# ### 9) String Compression
# - `aaabbcccc` → `a3b2c4`
# - `xxxyyyz` → `x3y3z1`
# - `abcd` → `a1b1c1d1`

# %%
s = input('enter string:')
res = "".join(
    s[i] + str(sum(1 for j in range(i, len(s)) if s[j] == s[i]))
    for i in range(len(s))
    if i == 0 or s[i] != s[i-1]
)

print(res)
# Out:
# enter string: aaabbcccc
# a3b2c4

# %% [markdown]
# ### 10) Toggle Case (without using str.swapcase())
# - `PyThOn` → `pYtHoN`
# - `HELlo` → `helLO`
# - `Python` → `pYTHON`

# %%
s = input('enter string:')
res = ' '
for i in s:
    if i.isupper():
        res = res +(i.lower())
    else:
        res = res + (i.upper())
print(res)
# Out:
# enter string: PyThOn
#  pYtHoN

# %% [markdown]
# ### 11) Username Validation
# #### valid username rules:
# 1. only alphabets and digits
# 2. does not start with a digit
# 3. length ≥ 6
#
# - `User123` → Valid
# - `123User` → Invalid
# - `Us@12` → Invalid

# %%
s = input('enter string:')
flag = True
if(s[0].isdigit() or len(s)<6):
    flag = False
if flag:
    for i in range (len(s)):
        if(not s[i].isalnum()):
            flag = False
            break
    else:
            print('valid')
else:
    print('invalid')
# Out:
# enter string: User123
# valid

# %% [markdown]
# ### 12) Palindrome Checker (ignore the case)
# - `Madam` → Palindrome
# - `Level` → Palindrome
# - `Python` → Not Palindrome

# %%
s = input('enter string:')
s = s.lower()
if s == s[::-1]:
    print('is palindrome')
else:
    print('not palindrome')
# Out:
# enter string: kasak
# is palindrome

# %% [markdown]
# ### 13) Longest Word Finder
# - `Python programming is interesting` → programming
# - `I love coding` → coding
# - `Data structures and algorithms` → structures

# %%
# s = input('enter string:')
s = "Python programming is interesting"

print(max(s.split(), key=len))
print(max("I love coding".split(), key=len))                     # coding
print(max("Data structures and algorithms".split(), key=len))   # structures
# Out:
# programming
# coding
# structures

# %% [markdown]
# ### 14) Case Conversion
# - `python programming`
#   - Upper: PYTHON PROGRAMMING
#   - Lower: python programming
#   - Title: Python Programming
#   - Capitalize: Python programming

# %%
s = input('enter string:')
upper = s.upper()
lower = s.lower()
Title = s.title()
capitalize = s.capitalize()
print(f'upper:{upper}')
print(f'lower:{lower}')
print(f'Title:{Title}')
print(f'capitalize:{capitalize}')
# Out:
# enter string: python programming
# upper:PYTHON PROGRAMMING
# lower:python programming
# Title:Python Programming
# capitalize:Python programming

# %% [markdown]
# ### 15) Custom Split
# - `apple,banana,grape`
# - `10|20|30`
# - `A-B-C-D`

# %%
s = input('enter string:')
s.split(',')
# Out:
# enter string: apple,banana,grape
# ['apple', 'banana', 'grape']

# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
name = input("Enter name:")
print("Hello" , name , "welcome to python lab!")
# Out:
# Enter name: priya
# Hello priya welcome to python lab!

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
a = int(input("enter number1:"))
b = int(input("enter number2:"))
c = int(input("enter number3:"))
print(a+b+c)
avg=(a+b+c)/3
print(int(avg))
# Out:
# enter number1: 10
# enter number2: 20
# enter number3: 30
# 60
# 20

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
name = input("enter name:")
age = int(input("enter age:"))
percentage = float(input("enter percentage:"))
print(name,type(name))
print(age,type(age))
print(percentage,type(percentage))
# Out:
# enter name: kasak
# enter age: 19
# enter percentage: 97.67
# kasak <class 'str'>
# 19 <class 'int'>
# 97.67 <class 'float'>

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print("python","programming","basics",sep="|",end="###")
# Out:
# python|programming|basics###

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
hello = input("enter input")
print("value:",hello)
print("type:",type(hello))
print("ID:",id(hello))
# Out:
# enter input hello
# value: hello
# type: <class 'str'>
# ID: 1571286620496

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
value = 10
print("original id of value",id(value))
value = 20
print("new id of value",id(value))
# Out:
# original id of value 140725779018952
# new id of value 140725779019272

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print(" welcome to python \n this is second lab \n enjoying coding!")
# Out:
#  welcome to python
#  this is second lab
#  enjoying coding!

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
print(f"{'Sr No':>5} {'Name':^10}  {'Subject':^10} {'Grade':5} {'percentage':10}")
print(f"{'1':>5}  {'Nisha patel':10} {'math':<11} {'A':5} {'92':10}")
print(f"{'2':>5}  {'Aarav modi':11} {'science':<10}  {'B+':5} {'85':10}")
print(f"{'3':>5}  {'jiya shah':11} {'english':<10}  {'A+':5} {'96':10}")
# Out:
# Sr No    Name      Subject   Grade percentage
#     1  Nisha patel math        A     92
#     2  Aarav modi  science     B+    85
#     3  jiya shah   english     A+    96

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
number = float(input("enter number:"))
print(f"2 decimal:{number : .2f}")
print(f"3 decimal:{number : .3f}")
print(f"width:{number : 10.2f}")
# Out:
# enter number: 49.2425
# 2 decimal: 49.24
# 3 decimal: 49.242
# width:     49.24

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
a = int(input("enter number:"))
b = int(input("enter number:"))
print(a+b)
print(a-b)
print(a*b)
# Out:
# enter number: 12
# enter number: 8
# 20
# 4
# 96

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
a = int(input("enter number:"))
b = int(input("enter number:"))
c = int(input("enter number:"))
print(a,b,c,sep="/")
print(c,b,a,sep="-")
# Out:
# enter number: 1
# enter number: 12
# enter number: 2025
# 1/12/2025
# 2025-12-1

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
r =float(input("enter radius"))
print(3.1415*r**2)
print(2*3.1415*r)
# Out:
# enter radius 5
# 78.53750000000001
# 31.415000000000003

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
c = float(input("Celsius: "))
print("Fahrenheit:", (c * 9/5) + 32)

f = float(input("Fahrenheit: "))
print("Celsius:", (f - 32) * 5/9)
# Out:
# Celsius:  45
# Fahrenheit: 113.0
# Fahrenheit:  56
# Celsius: 13.333333333333334

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
km = float(input("Enter distance in kilometers: "))

print("Meters:", km * 1000)
print("Centimeters:", km * 100000)
print("Feet:", km * 3280.84)
print("Inches:", km * 39370.1)
# Out:
# Enter distance in kilometers:  45
# Meters: 45000.0
# Centimeters: 4500000.0
# Feet: 147637.80000000002
# Inches: 1771654.5

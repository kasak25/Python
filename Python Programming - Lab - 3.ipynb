# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 3</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
A = int(input("enter number:"))
if A>0:
    print(A ,"is positive number!")
else:
    print(A,"is negative number!")
# Out:
# enter number: -5
# -5 is negative number!

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even.

# %%
A = int(input("enter number:"))
if A%2 == 0:
    print("is even number!")
else:
    print("is odd number!")
# Out:
# enter number: 9
# is odd number!

# %% [markdown]
# ### 03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
A = int(input("enter number:"))
B = int(input("enter number:"))
result = print(A,"is greater!") if A>B else print(B, "is greater")
# Out:
# enter number: 4
# enter number: 5
# 5 is greater

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
A = int(input("enter number:"))
B = int(input("enter number:"))
C = int(input("enter number:"))
# if A>B:
#     if A>C:
#         print(A,'is greater')
#     else:
#         print(B,'is greater')
# else:
#     print(C,'is greater')
result = print(A,'is greater') if (A>B and A>C) else print(B,'is greater')  if B>C else print(C,'is greater')
# Out:
# enter number: 5
# enter number: 8
# enter number: 9
# 9 is greater

# %% [markdown]
# ### 05) WAP to check whether the given year is leap year or not.
# #### [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
year = int(input("enter year:"))
if year%400 == 0 or year%4==0 and year%100!=0:
    print('is leap year')
else:
    print('is not leap year')
# Out:
# enter year: 2005
# is not leap year

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user.

# %%
choice = int(input("enter choice between 1 to 7:"))
match choice:
    case 1:
        print('monday')
    case 2:
        print('tuesday')
    case 3:
        print('wednesday')
    case 4:
        print('thursday')
    case 5:
        print('friday')
    case 6:
        print('saturday')
    case 7:
        print('sunday')
    case _:
        print('invalid choice')
# Out:
# enter choice between 1 to 7: 5
# friday

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %%
A = int(input("enter number:"))
B = int(input("enter number:"))
choice = int(input("enter choice between 1 to 5:"))
if choice == 1:
    print(A+B)
elif choice == 2:
    print(A-B)
elif choice == 3:
    print(A*B)
elif choice == 4:
    print(A/B)
elif choice == 5:
    print(A%B)
else:
    print('invalid choice')
# Out:
# enter number: 5
# enter number: 4
# enter choice between 1 to 5: 2
# 1

# %% [markdown]
# ### 08) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# #### Fail below 35
# #### Pass Class between 35 to 45
# #### Second Class
# #### between 45 to 60
# #### First Class between 60 to 70
# #### Distinction if more than 70

# %%
sub1 = int(input("enter number:"))
sub2 = int(input("enter number:"))
sub3 = int(input("enter number:"))
sub4 = int(input("enter number:"))
sub5 = int(input("enter number:"))
result = (sub1+sub2+sub3+sub4+sub5)/5
print(float(result))
if result < 35.0:
    print('fail')
elif result <45 and result>35:
    print('pass class')
elif result <60 and result>45:
    print('second class')
elif result<70 and result > 60:
    print('frist class')
elif result >70:
    print('distinction!')
# Out:
# enter number: 80
# enter number: 82
# enter number: 83
# enter number: 84
# enter number: 85
# 82.8
# distinction!

# %% [markdown]
# ### 09) WAP to find the second largest number among three user input numbers.

# %%
n1 = int(input("enter number:"))
n2 = int(input("enter number:"))
n3 = int(input("enter number:"))
if (n1<n2 and n1>n3) or (n1>n2 and n1<n3):
    print(n1,'is second largest')
elif(n2>n1 and n2<n3) or (n2<n3 and n1>n3):
    print(n2,'is second largest')
elif(n3>n1 and n3<n2) or (n3<n1 and n3>n2):
    print(n3,'is second largest')
# Out:
# enter number: 5
# enter number: 8
# enter number: 9
# 8 is second largest

# %% [markdown]
# ### 10) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# #### a. First 1 to 50 units – Rs. 2.60/unit
# #### b. Next 50 to 100 units – Rs. 3.25/unit
# #### c. Next 100 to 200 units – Rs. 5.26/unit
# #### d. above 200 units – Rs. 8.45/unit

# %%
unit = int(input('entr number:'))
if unit >=1 and unit <=50:
    bill = unit * 2.60
elif unit >50 and unit<= 100:
    bill = 50 * 2.60 + (unit - 50)*3.25
elif unit >100 and unit<= 200:
    bill = 50 * 2.60 +50 * 3.25+ (unit - 100)* 5.26
elif unit >200:
    bill = 50 * 2.60 +50 * 3.25 + 100*5.26+ (unit - 200)*8.45
else:
    print('invalid')
print(bill)
# Out:
# entr number: 125
# 424.0
